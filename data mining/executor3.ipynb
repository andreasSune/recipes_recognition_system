# %%
import pandas as pd
from recipe_family_classifier_pipe import *
from dotenv import load_dotenv
import os
from pathlib import Path
# Charger les variables du fichier .env
load_dotenv()
# Out:
# True

# %%
OPENROUTER_API_KEY = os.getenv('OPENROUTER_API_KEY_1')
MODEL_NAME = os.getenv('MODEL_NAME_5')

# %%
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent   
DATA_DIR = PROJECT_ROOT / "data"

# %%
recipe = pd.read_csv(DATA_DIR / "recipes.csv")
ingredients = pd.read_csv(DATA_DIR / "ingredients_with_titles.csv")

# %%
if __name__ == "__main__":

    #exécuteur 1 → df_all.iloc[0:205944]
    # Exécuteur 2 → df_all.iloc[205944:411888]
    # Exécuteur 3 → df_all.iloc[411888:617832]
    # Exécuteur 4 → df_all.iloc[617832:823776]
    # Exécuteur 5 → df_all.iloc[823776:1029720]
  
    df, metadata = classify_recipes_pipeline(
         titles_source= recipe.iloc[411888:617832],
         ingredients_source= ingredients,
         subset="3",
         api_key= OPENROUTER_API_KEY,
         model_name= MODEL_NAME,
         output_dir= DATA_DIR/"recipes_family",
     )

    # ── Charger les résultats plus tard ─────────────────────────
    # df = load_classification_results("./output_classification/recipe_classifications_subset1_XXXX.csv")
    # pates = get_recipes_by_family(df, "PATES")
    # pates_soupe = get_recipes_by_family(df, "PATES", type_plat="SOUPE")
    # na_recettes = get_na_recipes(df)
# Out:
# ============================================================
#   PIPELINE DE CLASSIFICATION DES FAMILLES DE RECETTES
#   Laboratoire Liara — UQAC
# ============================================================
#   Subset      : 3
#   Modèle      : openai/gpt-5.4-nano
#   Batch size  : 50
#   Save every  : 200 batches
#   Max retries : 5 (délai x3 min)
#   Pause 10b   : 30s | Pause 50b : 60s
#   Sortie      : C:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data\recipes_family
# ============================================================
#   🔄 Checkpoint trouvé → reprise passe 1, batch 1210
#      (60500 résultats P1, 0 résultats P2 déjà sauvegardés)
#   ▶️  Reprise depuis passe 1, batch 1210
#
#
# 📂 Chargement des données...
#   ✅ 205944 recettes chargées (subset 3)
#   ✅ Dataset ingrédients chargé : 1029720 entrées
#
# ────────────────────────────────────────────────────────────
#   PASSE 1 — Classification par titre seul
# ────────────────────────────────────────────────────────────
#   205944 recettes → 4119 batches de 50
#
#   [Batch 1/4119] ⏭️  déjà traité — skip
#   [Batch 2/4119] ⏭️  déjà traité — skip
#   [Batch 3/4119] ⏭️  déjà traité — skip
#   [Batch 4/4119] ⏭️  déjà traité — skip
#   [Batch 5/4119] ⏭️  déjà traité — skip
#   [Batch 6/4119] ⏭️  déjà traité — skip
#   [Batch 7/4119] ⏭️  déjà traité — skip
#   [Batch 8/4119] ⏭️  déjà traité — skip
#   [Batch 9/4119] ⏭️  déjà traité — skip
#   [Batch 10/4119] ⏭️  déjà traité — skip
#   [Batch 11/4119] ⏭️  déjà traité — skip
#   [Batch 12/4119] ⏭️  déjà traité — skip
#   [Batch 13/4119] ⏭️  déjà traité — skip
#   [Batch 14/4119] ⏭️  déjà traité — skip
#   [Batch 15/4119] ⏭️  déjà traité — skip
#   [Batch 16/4119] ⏭️  déjà traité — skip
#   [Batch 17/4119] ⏭️  déjà traité — skip
#   [Batch 18/4119] ⏭️  déjà traité — skip
#   [Batch 19/4119] ⏭️  déjà traité — skip
#   [Batch 20/4119] ⏭️  déjà traité — skip
#   [Batch 21/4119] ⏭️  déjà traité — skip
#   [Batch 22/4119] ⏭️  déjà traité — skip
#   [Batch 23/4119] ⏭️  déjà traité — skip
#   [Batch 24/4119] ⏭️  déjà traité — skip
#   [Batch 25/4119] ⏭️  déjà traité — skip
#   [Batch 26/4119] ⏭️  déjà traité — skip
#   [Batch 27/4119] ⏭️  déjà traité — skip
#   [Batch 28/4119] ⏭️  déjà traité — skip
#   [Batch 29/4119] ⏭️  déjà traité — skip
#   [Batch 30/4119] ⏭️  déjà traité — skip
#   [Batch 31/4119] ⏭️  déjà traité — skip
#   [Batch 32/4119] ⏭️  déjà traité — skip
#   [Batch 33/4119] ⏭️  déjà traité — skip
#   [Batch 34/4119] ⏭️  déjà traité — skip
#   [Batch 35/4119] ⏭️  déjà traité — skip
#   [Batch 36/4119] ⏭️  déjà traité — skip
#   [Batch 37/4119] ⏭️  déjà traité — skip
#   [Batch 38/4119] ⏭️  déjà traité — skip
#   [Batch 39/4119] ⏭️  déjà traité — skip
#   [Batch 40/4119] ⏭️  déjà traité — skip
#   [Batch 41/4119] ⏭️  déjà traité — skip
#   [Batch 42/4119] ⏭️  déjà traité — skip
#   [Batch 43/4119] ⏭️  déjà traité — skip
#   [Batch 44/4119] ⏭️  déjà traité — skip
#   [Batch 45/4119] ⏭️  déjà traité — skip
#   [Batch 46/4119] ⏭️  déjà traité — skip
#   [Batch 47/4119] ⏭️  déjà traité — skip
#   [Batch 48/4119] ⏭️  déjà traité — skip
#   [Batch 49/4119] ⏭️  déjà traité — skip
#   [Batch 50/4119] ⏭️  déjà traité — skip
#   [Batch 51/4119] ⏭️  déjà traité — skip
#   [Batch 52/4119] ⏭️  déjà traité — skip
#   [Batch 53/4119] ⏭️  déjà traité — skip
#   [Batch 54/4119] ⏭️  déjà traité — skip
#   [Batch 55/4119] ⏭️  déjà traité — skip
#   [Batch 56/4119] ⏭️  déjà traité — skip
#   [Batch 57/4119] ⏭️  déjà traité — skip
#   [Batch 58/4119] ⏭️  déjà traité — skip
#   [Batch 59/4119] ⏭️  déjà traité — skip
#   [Batch 60/4119] ⏭️  déjà traité — skip
#   [Batch 61/4119] ⏭️  déjà traité — skip
#   [Batch 62/4119] ⏭️  déjà traité — skip
#   [Batch 63/4119] ⏭️  déjà traité — skip
#   [Batch 64/4119] ⏭️  déjà traité — skip
#   [Batch 65/4119] ⏭️  déjà traité — skip
#   [Batch 66/4119] ⏭️  déjà traité — skip
#   [Batch 67/4119] ⏭️  déjà traité — skip
#   [Batch 68/4119] ⏭️  déjà traité — skip
#   [Batch 69/4119] ⏭️  déjà traité — skip
#   [Batch 70/4119] ⏭️  déjà traité — skip
#   [Batch 71/4119] ⏭️  déjà traité — skip
#   [Batch 72/4119] ⏭️  déjà traité — skip
#   [Batch 73/4119] ⏭️  déjà traité — skip
#   [Batch 74/4119] ⏭️  déjà traité — skip
#   [Batch 75/4119] ⏭️  déjà traité — skip
#   [Batch 76/4119] ⏭️  déjà traité — skip
#   [Batch 77/4119] ⏭️  déjà traité — skip
#   [Batch 78/4119] ⏭️  déjà traité — skip
#   [Batch 79/4119] ⏭️  déjà traité — skip
#   [Batch 80/4119] ⏭️  déjà traité — skip
#   [Batch 81/4119] ⏭️  déjà traité — skip
#   [Batch 82/4119] ⏭️  déjà traité — skip
#   [Batch 83/4119] ⏭️  déjà traité — skip
#   [Batch 84/4119] ⏭️  déjà traité — skip
#   [Batch 85/4119] ⏭️  déjà traité — skip
#   [Batch 86/4119] ⏭️  déjà traité — skip
#   [Batch 87/4119] ⏭️  déjà traité — skip
#   [Batch 88/4119] ⏭️  déjà traité — skip
#   [Batch 89/4119] ⏭️  déjà traité — skip
#   [Batch 90/4119] ⏭️  déjà traité — skip
#   [Batch 91/4119] ⏭️  déjà traité — skip
#   [Batch 92/4119] ⏭️  déjà traité — skip
#   [Batch 93/4119] ⏭️  déjà traité — skip
#   [Batch 94/4119] ⏭️  déjà traité — skip
#   [Batch 95/4119] ⏭️  déjà traité — skip
#   [Batch 96/4119] ⏭️  déjà traité — skip
#   [Batch 97/4119] ⏭️  déjà traité — skip
#   [Batch 98/4119] ⏭️  déjà traité — skip
#   [Batch 99/4119] ⏭️  déjà traité — skip
#   [Batch 100/4119] ⏭️  déjà traité — skip
#   [Batch 101/4119] ⏭️  déjà traité — skip
#   [Batch 102/4119] ⏭️  déjà traité — skip
#   [Batch 103/4119] ⏭️  déjà traité — skip
#   [Batch 104/4119] ⏭️  déjà traité — skip
#   [Batch 105/4119] ⏭️  déjà traité — skip
#   [Batch 106/4119] ⏭️  déjà traité — skip
#   [Batch 107/4119] ⏭️  déjà traité — skip
#   [Batch 108/4119] ⏭️  déjà traité — skip
#   [Batch 109/4119] ⏭️  déjà traité — skip
#   [Batch 110/4119] ⏭️  déjà traité — skip
#   [Batch 111/4119] ⏭️  déjà traité — skip
#   [Batch 112/4119] ⏭️  déjà traité — skip
#   [Batch 113/4119] ⏭️  déjà traité — skip
#   [Batch 114/4119] ⏭️  déjà traité — skip
#   [Batch 115/4119] ⏭️  déjà traité — skip
#   [Batch 116/4119] ⏭️  déjà traité — skip
#   [Batch 117/4119] ⏭️  déjà traité — skip
#   [Batch 118/4119] ⏭️  déjà traité — skip
#   [Batch 119/4119] ⏭️  déjà traité — skip
#   [Batch 120/4119] ⏭️  déjà traité — skip
#   [Batch 121/4119] ⏭️  déjà traité — skip
#   [Batch 122/4119] ⏭️  déjà traité — skip
#   [Batch 123/4119] ⏭️  déjà traité — skip
#   [Batch 124/4119] ⏭️  déjà traité — skip
#   [Batch 125/4119] ⏭️  déjà traité — skip
#   [Batch 126/4119] ⏭️  déjà traité — skip
#   [Batch 127/4119] ⏭️  déjà traité — skip
#   [Batch 128/4119] ⏭️  déjà traité — skip
#   [Batch 129/4119] ⏭️  déjà traité — skip
#   [Batch 130/4119] ⏭️  déjà traité — skip
#   [Batch 131/4119] ⏭️  déjà traité — skip
#   [Batch 132/4119] ⏭️  déjà traité — skip
#   [Batch 133/4119] ⏭️  déjà traité — skip
#   [Batch 134/4119] ⏭️  déjà traité — skip
#   [Batch 135/4119] ⏭️  déjà traité — skip
#   [Batch 136/4119] ⏭️  déjà traité — skip
#   [Batch 137/4119] ⏭️  déjà traité — skip
#   [Batch 138/4119] ⏭️  déjà traité — skip
#   [Batch 139/4119] ⏭️  déjà traité — skip
#   [Batch 140/4119] ⏭️  déjà traité — skip
#   [Batch 141/4119] ⏭️  déjà traité — skip
#   [Batch 142/4119] ⏭️  déjà traité — skip
#   [Batch 143/4119] ⏭️  déjà traité — skip
#   [Batch 144/4119] ⏭️  déjà traité — skip
#   [Batch 145/4119] ⏭️  déjà traité — skip
#   [Batch 146/4119] ⏭️  déjà traité — skip
#   [Batch 147/4119] ⏭️  déjà traité — skip
#   [Batch 148/4119] ⏭️  déjà traité — skip
#   [Batch 149/4119] ⏭️  déjà traité — skip
#   [Batch 150/4119] ⏭️  déjà traité — skip
#   [Batch 151/4119] ⏭️  déjà traité — skip
#   [Batch 152/4119] ⏭️  déjà traité — skip
#   [Batch 153/4119] ⏭️  déjà traité — skip
#   [Batch 154/4119] ⏭️  déjà traité — skip
#   [Batch 155/4119] ⏭️  déjà traité — skip
#   [Batch 156/4119] ⏭️  déjà traité — skip
#   [Batch 157/4119] ⏭️  déjà traité — skip
#   [Batch 158/4119] ⏭️  déjà traité — skip
#   [Batch 159/4119] ⏭️  déjà traité — skip
#   [Batch 160/4119] ⏭️  déjà traité — skip
#   [Batch 161/4119] ⏭️  déjà traité — skip
#   [Batch 162/4119] ⏭️  déjà traité — skip
#   [Batch 163/4119] ⏭️  déjà traité — skip
#   [Batch 164/4119] ⏭️  déjà traité — skip
#   [Batch 165/4119] ⏭️  déjà traité — skip
#   [Batch 166/4119] ⏭️  déjà traité — skip
#   [Batch 167/4119] ⏭️  déjà traité — skip
#   [Batch 168/4119] ⏭️  déjà traité — skip
#   [Batch 169/4119] ⏭️  déjà traité — skip
#   [Batch 170/4119] ⏭️  déjà traité — skip
#   [Batch 171/4119] ⏭️  déjà traité — skip
#   [Batch 172/4119] ⏭️  déjà traité — skip
#   [Batch 173/4119] ⏭️  déjà traité — skip
#   [Batch 174/4119] ⏭️  déjà traité — skip
#   [Batch 175/4119] ⏭️  déjà traité — skip
#   [Batch 176/4119] ⏭️  déjà traité — skip
#   [Batch 177/4119] ⏭️  déjà traité — skip
#   [Batch 178/4119] ⏭️  déjà traité — skip
#   [Batch 179/4119] ⏭️  déjà traité — skip
#   [Batch 180/4119] ⏭️  déjà traité — skip
#   [Batch 181/4119] ⏭️  déjà traité — skip
#   [Batch 182/4119] ⏭️  déjà traité — skip
#   [Batch 183/4119] ⏭️  déjà traité — skip
#   [Batch 184/4119] ⏭️  déjà traité — skip
#   [Batch 185/4119] ⏭️  déjà traité — skip
#   [Batch 186/4119] ⏭️  déjà traité — skip
#   [Batch 187/4119] ⏭️  déjà traité — skip
#   [Batch 188/4119] ⏭️  déjà traité — skip
#   [Batch 189/4119] ⏭️  déjà traité — skip
#   [Batch 190/4119] ⏭️  déjà traité — skip
#   [Batch 191/4119] ⏭️  déjà traité — skip
#   [Batch 192/4119] ⏭️  déjà traité — skip
#   [Batch 193/4119] ⏭️  déjà traité — skip
#   [Batch 194/4119] ⏭️  déjà traité — skip
#   [Batch 195/4119] ⏭️  déjà traité — skip
#   [Batch 196/4119] ⏭️  déjà traité — skip
#   [Batch 197/4119] ⏭️  déjà traité — skip
#   [Batch 198/4119] ⏭️  déjà traité — skip
#   [Batch 199/4119] ⏭️  déjà traité — skip
#   [Batch 200/4119] ⏭️  déjà traité — skip
#   [Batch 201/4119] ⏭️  déjà traité — skip
#   [Batch 202/4119] ⏭️  déjà traité — skip
#   [Batch 203/4119] ⏭️  déjà traité — skip
#   [Batch 204/4119] ⏭️  déjà traité — skip
#   [Batch 205/4119] ⏭️  déjà traité — skip
#   [Batch 206/4119] ⏭️  déjà traité — skip
#   [Batch 207/4119] ⏭️  déjà traité — skip
#   [Batch 208/4119] ⏭️  déjà traité — skip
#   [Batch 209/4119] ⏭️  déjà traité — skip
#   [Batch 210/4119] ⏭️  déjà traité — skip
#   [Batch 211/4119] ⏭️  déjà traité — skip
#   [Batch 212/4119] ⏭️  déjà traité — skip
#   [Batch 213/4119] ⏭️  déjà traité — skip
#   [Batch 214/4119] ⏭️  déjà traité — skip
#   [Batch 215/4119] ⏭️  déjà traité — skip
#   [Batch 216/4119] ⏭️  déjà traité — skip
#   [Batch 217/4119] ⏭️  déjà traité — skip
#   [Batch 218/4119] ⏭️  déjà traité — skip
#   [Batch 219/4119] ⏭️  déjà traité — skip
#   [Batch 220/4119] ⏭️  déjà traité — skip
#   [Batch 221/4119] ⏭️  déjà traité — skip
#   [Batch 222/4119] ⏭️  déjà traité — skip
#   [Batch 223/4119] ⏭️  déjà traité — skip
#   [Batch 224/4119] ⏭️  déjà traité — skip
#   [Batch 225/4119] ⏭️  déjà traité — skip
#   [Batch 226/4119] ⏭️  déjà traité — skip
#   [Batch 227/4119] ⏭️  déjà traité — skip
#   [Batch 228/4119] ⏭️  déjà traité — skip
#   [Batch 229/4119] ⏭️  déjà traité — skip
#   [Batch 230/4119] ⏭️  déjà traité — skip
#   [Batch 231/4119] ⏭️  déjà traité — skip
#   [Batch 232/4119] ⏭️  déjà traité — skip
#   [Batch 233/4119] ⏭️  déjà traité — skip
#   [Batch 234/4119] ⏭️  déjà traité — skip
#   [Batch 235/4119] ⏭️  déjà traité — skip
#   [Batch 236/4119] ⏭️  déjà traité — skip
#   [Batch 237/4119] ⏭️  déjà traité — skip
#   [Batch 238/4119] ⏭️  déjà traité — skip
#   [Batch 239/4119] ⏭️  déjà traité — skip
#   [Batch 240/4119] ⏭️  déjà traité — skip
#   [Batch 241/4119] ⏭️  déjà traité — skip
#   [Batch 242/4119] ⏭️  déjà traité — skip
#   [Batch 243/4119] ⏭️  déjà traité — skip
#   [Batch 244/4119] ⏭️  déjà traité — skip
#   [Batch 245/4119] ⏭️  déjà traité — skip
#   [Batch 246/4119] ⏭️  déjà traité — skip
#   [Batch 247/4119] ⏭️  déjà traité — skip
#   [Batch 248/4119] ⏭️  déjà traité — skip
#   [Batch 249/4119] ⏭️  déjà traité — skip
#   [Batch 250/4119] ⏭️  déjà traité — skip
#   [Batch 251/4119] ⏭️  déjà traité — skip
#   [Batch 252/4119] ⏭️  déjà traité — skip
#   [Batch 253/4119] ⏭️  déjà traité — skip
#   [Batch 254/4119] ⏭️  déjà traité — skip
#   [Batch 255/4119] ⏭️  déjà traité — skip
#   [Batch 256/4119] ⏭️  déjà traité — skip
#   [Batch 257/4119] ⏭️  déjà traité — skip
#   [Batch 258/4119] ⏭️  déjà traité — skip
#   [Batch 259/4119] ⏭️  déjà traité — skip
#   [Batch 260/4119] ⏭️  déjà traité — skip
#   [Batch 261/4119] ⏭️  déjà traité — skip
#   [Batch 262/4119] ⏭️  déjà traité — skip
#   [Batch 263/4119] ⏭️  déjà traité — skip
#   [Batch 264/4119] ⏭️  déjà traité — skip
#   [Batch 265/4119] ⏭️  déjà traité — skip
#   [Batch 266/4119] ⏭️  déjà traité — skip
#   [Batch 267/4119] ⏭️  déjà traité — skip
#   [Batch 268/4119] ⏭️  déjà traité — skip
#   [Batch 269/4119] ⏭️  déjà traité — skip
#   [Batch 270/4119] ⏭️  déjà traité — skip
#   [Batch 271/4119] ⏭️  déjà traité — skip
#   [Batch 272/4119] ⏭️  déjà traité — skip
#   [Batch 273/4119] ⏭️  déjà traité — skip
#   [Batch 274/4119] ⏭️  déjà traité — skip
#   [Batch 275/4119] ⏭️  déjà traité — skip
#   [Batch 276/4119] ⏭️  déjà traité — skip
#   [Batch 277/4119] ⏭️  déjà traité — skip
#   [Batch 278/4119] ⏭️  déjà traité — skip
#   [Batch 279/4119] ⏭️  déjà traité — skip
#   [Batch 280/4119] ⏭️  déjà traité — skip
#   [Batch 281/4119] ⏭️  déjà traité — skip
#   [Batch 282/4119] ⏭️  déjà traité — skip
#   [Batch 283/4119] ⏭️  déjà traité — skip
#   [Batch 284/4119] ⏭️  déjà traité — skip
#   [Batch 285/4119] ⏭️  déjà traité — skip
#   [Batch 286/4119] ⏭️  déjà traité — skip
#   [Batch 287/4119] ⏭️  déjà traité — skip
#   [Batch 288/4119] ⏭️  déjà traité — skip
#   [Batch 289/4119] ⏭️  déjà traité — skip
#   [Batch 290/4119] ⏭️  déjà traité — skip
#   [Batch 291/4119] ⏭️  déjà traité — skip
#   [Batch 292/4119] ⏭️  déjà traité — skip
#   [Batch 293/4119] ⏭️  déjà traité — skip
#   [Batch 294/4119] ⏭️  déjà traité — skip
#   [Batch 295/4119] ⏭️  déjà traité — skip
#   [Batch 296/4119] ⏭️  déjà traité — skip
#   [Batch 297/4119] ⏭️  déjà traité — skip
#   [Batch 298/4119] ⏭️  déjà traité — skip
#   [Batch 299/4119] ⏭️  déjà traité — skip
#   [Batch 300/4119] ⏭️  déjà traité — skip
#   [Batch 301/4119] ⏭️  déjà traité — skip
#   [Batch 302/4119] ⏭️  déjà traité — skip
#   [Batch 303/4119] ⏭️  déjà traité — skip
#   [Batch 304/4119] ⏭️  déjà traité — skip
#   [Batch 305/4119] ⏭️  déjà traité — skip
#   [Batch 306/4119] ⏭️  déjà traité — skip
#   [Batch 307/4119] ⏭️  déjà traité — skip
#   [Batch 308/4119] ⏭️  déjà traité — skip
#   [Batch 309/4119] ⏭️  déjà traité — skip
#   [Batch 310/4119] ⏭️  déjà traité — skip
#   [Batch 311/4119] ⏭️  déjà traité — skip
#   [Batch 312/4119] ⏭️  déjà traité — skip
#   [Batch 313/4119] ⏭️  déjà traité — skip
#   [Batch 314/4119] ⏭️  déjà traité — skip
#   [Batch 315/4119] ⏭️  déjà traité — skip
#   [Batch 316/4119] ⏭️  déjà traité — skip
#   [Batch 317/4119] ⏭️  déjà traité — skip
#   [Batch 318/4119] ⏭️  déjà traité — skip
#   [Batch 319/4119] ⏭️  déjà traité — skip
#   [Batch 320/4119] ⏭️  déjà traité — skip
#   [Batch 321/4119] ⏭️  déjà traité — skip
#   [Batch 322/4119] ⏭️  déjà traité — skip
#   [Batch 323/4119] ⏭️  déjà traité — skip
#   [Batch 324/4119] ⏭️  déjà traité — skip
#   [Batch 325/4119] ⏭️  déjà traité — skip
#   [Batch 326/4119] ⏭️  déjà traité — skip
#   [Batch 327/4119] ⏭️  déjà traité — skip
#   [Batch 328/4119] ⏭️  déjà traité — skip
#   [Batch 329/4119] ⏭️  déjà traité — skip
#   [Batch 330/4119] ⏭️  déjà traité — skip
#   [Batch 331/4119] ⏭️  déjà traité — skip
#   [Batch 332/4119] ⏭️  déjà traité — skip
#   [Batch 333/4119] ⏭️  déjà traité — skip
#   [Batch 334/4119] ⏭️  déjà traité — skip
#   [Batch 335/4119] ⏭️  déjà traité — skip
#   [Batch 336/4119] ⏭️  déjà traité — skip
#   [Batch 337/4119] ⏭️  déjà traité — skip
#   [Batch 338/4119] ⏭️  déjà traité — skip
#   [Batch 339/4119] ⏭️  déjà traité — skip
#   [Batch 340/4119] ⏭️  déjà traité — skip
#   [Batch 341/4119] ⏭️  déjà traité — skip
#   [Batch 342/4119] ⏭️  déjà traité — skip
#   [Batch 343/4119] ⏭️  déjà traité — skip
#   [Batch 344/4119] ⏭️  déjà traité — skip
#   [Batch 345/4119] ⏭️  déjà traité — skip
#   [Batch 346/4119] ⏭️  déjà traité — skip
#   [Batch 347/4119] ⏭️  déjà traité — skip
#   [Batch 348/4119] ⏭️  déjà traité — skip
#   [Batch 349/4119] ⏭️  déjà traité — skip
#   [Batch 350/4119] ⏭️  déjà traité — skip
#   [Batch 351/4119] ⏭️  déjà traité — skip
#   [Batch 352/4119] ⏭️  déjà traité — skip
#   [Batch 353/4119] ⏭️  déjà traité — skip
#   [Batch 354/4119] ⏭️  déjà traité — skip
#   [Batch 355/4119] ⏭️  déjà traité — skip
#   [Batch 356/4119] ⏭️  déjà traité — skip
#   [Batch 357/4119] ⏭️  déjà traité — skip
#   [Batch 358/4119] ⏭️  déjà traité — skip
#   [Batch 359/4119] ⏭️  déjà traité — skip
#   [Batch 360/4119] ⏭️  déjà traité — skip
#   [Batch 361/4119] ⏭️  déjà traité — skip
#   [Batch 362/4119] ⏭️  déjà traité — skip
#   [Batch 363/4119] ⏭️  déjà traité — skip
#   [Batch 364/4119] ⏭️  déjà traité — skip
#   [Batch 365/4119] ⏭️  déjà traité — skip
#   [Batch 366/4119] ⏭️  déjà traité — skip
#   [Batch 367/4119] ⏭️  déjà traité — skip
#   [Batch 368/4119] ⏭️  déjà traité — skip
#   [Batch 369/4119] ⏭️  déjà traité — skip
#   [Batch 370/4119] ⏭️  déjà traité — skip
#   [Batch 371/4119] ⏭️  déjà traité — skip
#   [Batch 372/4119] ⏭️  déjà traité — skip
#   [Batch 373/4119] ⏭️  déjà traité — skip
#   [Batch 374/4119] ⏭️  déjà traité — skip
#   [Batch 375/4119] ⏭️  déjà traité — skip
#   [Batch 376/4119] ⏭️  déjà traité — skip
#   [Batch 377/4119] ⏭️  déjà traité — skip
#   [Batch 378/4119] ⏭️  déjà traité — skip
#   [Batch 379/4119] ⏭️  déjà traité — skip
#   [Batch 380/4119] ⏭️  déjà traité — skip
#   [Batch 381/4119] ⏭️  déjà traité — skip
#   [Batch 382/4119] ⏭️  déjà traité — skip
#   [Batch 383/4119] ⏭️  déjà traité — skip
#   [Batch 384/4119] ⏭️  déjà traité — skip
#   [Batch 385/4119] ⏭️  déjà traité — skip
#   [Batch 386/4119] ⏭️  déjà traité — skip
#   [Batch 387/4119] ⏭️  déjà traité — skip
#   [Batch 388/4119] ⏭️  déjà traité — skip
#   [Batch 389/4119] ⏭️  déjà traité — skip
#   [Batch 390/4119] ⏭️  déjà traité — skip
#   [Batch 391/4119] ⏭️  déjà traité — skip
#   [Batch 392/4119] ⏭️  déjà traité — skip
#   [Batch 393/4119] ⏭️  déjà traité — skip
#   [Batch 394/4119] ⏭️  déjà traité — skip
#   [Batch 395/4119] ⏭️  déjà traité — skip
#   [Batch 396/4119] ⏭️  déjà traité — skip
#   [Batch 397/4119] ⏭️  déjà traité — skip
#   [Batch 398/4119] ⏭️  déjà traité — skip
#   [Batch 399/4119] ⏭️  déjà traité — skip
#   [Batch 400/4119] ⏭️  déjà traité — skip
#   [Batch 401/4119] ⏭️  déjà traité — skip
#   [Batch 402/4119] ⏭️  déjà traité — skip
#   [Batch 403/4119] ⏭️  déjà traité — skip
#   [Batch 404/4119] ⏭️  déjà traité — skip
#   [Batch 405/4119] ⏭️  déjà traité — skip
#   [Batch 406/4119] ⏭️  déjà traité — skip
#   [Batch 407/4119] ⏭️  déjà traité — skip
#   [Batch 408/4119] ⏭️  déjà traité — skip
#   [Batch 409/4119] ⏭️  déjà traité — skip
#   [Batch 410/4119] ⏭️  déjà traité — skip
#   [Batch 411/4119] ⏭️  déjà traité — skip
#   [Batch 412/4119] ⏭️  déjà traité — skip
#   [Batch 413/4119] ⏭️  déjà traité — skip
#   [Batch 414/4119] ⏭️  déjà traité — skip
#   [Batch 415/4119] ⏭️  déjà traité — skip
#   [Batch 416/4119] ⏭️  déjà traité — skip
#   [Batch 417/4119] ⏭️  déjà traité — skip
#   [Batch 418/4119] ⏭️  déjà traité — skip
#   [Batch 419/4119] ⏭️  déjà traité — skip
#   [Batch 420/4119] ⏭️  déjà traité — skip
#   [Batch 421/4119] ⏭️  déjà traité — skip
#   [Batch 422/4119] ⏭️  déjà traité — skip
#   [Batch 423/4119] ⏭️  déjà traité — skip
#   [Batch 424/4119] ⏭️  déjà traité — skip
#   [Batch 425/4119] ⏭️  déjà traité — skip
#   [Batch 426/4119] ⏭️  déjà traité — skip
#   [Batch 427/4119] ⏭️  déjà traité — skip
#   [Batch 428/4119] ⏭️  déjà traité — skip
#   [Batch 429/4119] ⏭️  déjà traité — skip
#   [Batch 430/4119] ⏭️  déjà traité — skip
#   [Batch 431/4119] ⏭️  déjà traité — skip
#   [Batch 432/4119] ⏭️  déjà traité — skip
#   [Batch 433/4119] ⏭️  déjà traité — skip
#   [Batch 434/4119] ⏭️  déjà traité — skip
#   [Batch 435/4119] ⏭️  déjà traité — skip
#   [Batch 436/4119] ⏭️  déjà traité — skip
#   [Batch 437/4119] ⏭️  déjà traité — skip
#   [Batch 438/4119] ⏭️  déjà traité — skip
#   [Batch 439/4119] ⏭️  déjà traité — skip
#   [Batch 440/4119] ⏭️  déjà traité — skip
#   [Batch 441/4119] ⏭️  déjà traité — skip
#   [Batch 442/4119] ⏭️  déjà traité — skip
#   [Batch 443/4119] ⏭️  déjà traité — skip
#   [Batch 444/4119] ⏭️  déjà traité — skip
#   [Batch 445/4119] ⏭️  déjà traité — skip
#   [Batch 446/4119] ⏭️  déjà traité — skip
#   [Batch 447/4119] ⏭️  déjà traité — skip
#   [Batch 448/4119] ⏭️  déjà traité — skip
#   [Batch 449/4119] ⏭️  déjà traité — skip
#   [Batch 450/4119] ⏭️  déjà traité — skip
#   [Batch 451/4119] ⏭️  déjà traité — skip
#   [Batch 452/4119] ⏭️  déjà traité — skip
#   [Batch 453/4119] ⏭️  déjà traité — skip
#   [Batch 454/4119] ⏭️  déjà traité — skip
#   [Batch 455/4119] ⏭️  déjà traité — skip
#   [Batch 456/4119] ⏭️  déjà traité — skip
#   [Batch 457/4119] ⏭️  déjà traité — skip
#   [Batch 458/4119] ⏭️  déjà traité — skip
#   [Batch 459/4119] ⏭️  déjà traité — skip
#   [Batch 460/4119] ⏭️  déjà traité — skip
#   [Batch 461/4119] ⏭️  déjà traité — skip
#   [Batch 462/4119] ⏭️  déjà traité — skip
#   [Batch 463/4119] ⏭️  déjà traité — skip
#   [Batch 464/4119] ⏭️  déjà traité — skip
#   [Batch 465/4119] ⏭️  déjà traité — skip
#   [Batch 466/4119] ⏭️  déjà traité — skip
#   [Batch 467/4119] ⏭️  déjà traité — skip
#   [Batch 468/4119] ⏭️  déjà traité — skip
#   [Batch 469/4119] ⏭️  déjà traité — skip
#   [Batch 470/4119] ⏭️  déjà traité — skip
#   [Batch 471/4119] ⏭️  déjà traité — skip
#   [Batch 472/4119] ⏭️  déjà traité — skip
#   [Batch 473/4119] ⏭️  déjà traité — skip
#   [Batch 474/4119] ⏭️  déjà traité — skip
#   [Batch 475/4119] ⏭️  déjà traité — skip
#   [Batch 476/4119] ⏭️  déjà traité — skip
#   [Batch 477/4119] ⏭️  déjà traité — skip
#   [Batch 478/4119] ⏭️  déjà traité — skip
#   [Batch 479/4119] ⏭️  déjà traité — skip
#   [Batch 480/4119] ⏭️  déjà traité — skip
#   [Batch 481/4119] ⏭️  déjà traité — skip
#   [Batch 482/4119] ⏭️  déjà traité — skip
#   [Batch 483/4119] ⏭️  déjà traité — skip
#   [Batch 484/4119] ⏭️  déjà traité — skip
#   [Batch 485/4119] ⏭️  déjà traité — skip
#   [Batch 486/4119] ⏭️  déjà traité — skip
#   [Batch 487/4119] ⏭️  déjà traité — skip
#   [Batch 488/4119] ⏭️  déjà traité — skip
#   [Batch 489/4119] ⏭️  déjà traité — skip
#   [Batch 490/4119] ⏭️  déjà traité — skip
#   [Batch 491/4119] ⏭️  déjà traité — skip
#   [Batch 492/4119] ⏭️  déjà traité — skip
#   [Batch 493/4119] ⏭️  déjà traité — skip
#   [Batch 494/4119] ⏭️  déjà traité — skip
#   [Batch 495/4119] ⏭️  déjà traité — skip
#   [Batch 496/4119] ⏭️  déjà traité — skip
#   [Batch 497/4119] ⏭️  déjà traité — skip
#   [Batch 498/4119] ⏭️  déjà traité — skip
#   [Batch 499/4119] ⏭️  déjà traité — skip
#   [Batch 500/4119] ⏭️  déjà traité — skip
#   [Batch 501/4119] ⏭️  déjà traité — skip
#   [Batch 502/4119] ⏭️  déjà traité — skip
#   [Batch 503/4119] ⏭️  déjà traité — skip
#   [Batch 504/4119] ⏭️  déjà traité — skip
#   [Batch 505/4119] ⏭️  déjà traité — skip
#   [Batch 506/4119] ⏭️  déjà traité — skip
#   [Batch 507/4119] ⏭️  déjà traité — skip
#   [Batch 508/4119] ⏭️  déjà traité — skip
#   [Batch 509/4119] ⏭️  déjà traité — skip
#   [Batch 510/4119] ⏭️  déjà traité — skip
#   [Batch 511/4119] ⏭️  déjà traité — skip
#   [Batch 512/4119] ⏭️  déjà traité — skip
#   [Batch 513/4119] ⏭️  déjà traité — skip
#   [Batch 514/4119] ⏭️  déjà traité — skip
#   [Batch 515/4119] ⏭️  déjà traité — skip
#   [Batch 516/4119] ⏭️  déjà traité — skip
#   [Batch 517/4119] ⏭️  déjà traité — skip
#   [Batch 518/4119] ⏭️  déjà traité — skip
#   [Batch 519/4119] ⏭️  déjà traité — skip
#   [Batch 520/4119] ⏭️  déjà traité — skip
#   [Batch 521/4119] ⏭️  déjà traité — skip
#   [Batch 522/4119] ⏭️  déjà traité — skip
#   [Batch 523/4119] ⏭️  déjà traité — skip
#   [Batch 524/4119] ⏭️  déjà traité — skip
#   [Batch 525/4119] ⏭️  déjà traité — skip
#   [Batch 526/4119] ⏭️  déjà traité — skip
#   [Batch 527/4119] ⏭️  déjà traité — skip
#   [Batch 528/4119] ⏭️  déjà traité — skip
#   [Batch 529/4119] ⏭️  déjà traité — skip
#   [Batch 530/4119] ⏭️  déjà traité — skip
#   [Batch 531/4119] ⏭️  déjà traité — skip
#   [Batch 532/4119] ⏭️  déjà traité — skip
#   [Batch 533/4119] ⏭️  déjà traité — skip
#   [Batch 534/4119] ⏭️  déjà traité — skip
#   [Batch 535/4119] ⏭️  déjà traité — skip
#   [Batch 536/4119] ⏭️  déjà traité — skip
#   [Batch 537/4119] ⏭️  déjà traité — skip
#   [Batch 538/4119] ⏭️  déjà traité — skip
#   [Batch 539/4119] ⏭️  déjà traité — skip
#   [Batch 540/4119] ⏭️  déjà traité — skip
#   [Batch 541/4119] ⏭️  déjà traité — skip
#   [Batch 542/4119] ⏭️  déjà traité — skip
#   [Batch 543/4119] ⏭️  déjà traité — skip
#   [Batch 544/4119] ⏭️  déjà traité — skip
#   [Batch 545/4119] ⏭️  déjà traité — skip
#   [Batch 546/4119] ⏭️  déjà traité — skip
#   [Batch 547/4119] ⏭️  déjà traité — skip
#   [Batch 548/4119] ⏭️  déjà traité — skip
#   [Batch 549/4119] ⏭️  déjà traité — skip
#   [Batch 550/4119] ⏭️  déjà traité — skip
#   [Batch 551/4119] ⏭️  déjà traité — skip
#   [Batch 552/4119] ⏭️  déjà traité — skip
#   [Batch 553/4119] ⏭️  déjà traité — skip
#   [Batch 554/4119] ⏭️  déjà traité — skip
#   [Batch 555/4119] ⏭️  déjà traité — skip
#   [Batch 556/4119] ⏭️  déjà traité — skip
#   [Batch 557/4119] ⏭️  déjà traité — skip
#   [Batch 558/4119] ⏭️  déjà traité — skip
#   [Batch 559/4119] ⏭️  déjà traité — skip
#   [Batch 560/4119] ⏭️  déjà traité — skip
#   [Batch 561/4119] ⏭️  déjà traité — skip
#   [Batch 562/4119] ⏭️  déjà traité — skip
#   [Batch 563/4119] ⏭️  déjà traité — skip
#   [Batch 564/4119] ⏭️  déjà traité — skip
#   [Batch 565/4119] ⏭️  déjà traité — skip
#   [Batch 566/4119] ⏭️  déjà traité — skip
#   [Batch 567/4119] ⏭️  déjà traité — skip
#   [Batch 568/4119] ⏭️  déjà traité — skip
#   [Batch 569/4119] ⏭️  déjà traité — skip
#   [Batch 570/4119] ⏭️  déjà traité — skip
#   [Batch 571/4119] ⏭️  déjà traité — skip
#   [Batch 572/4119] ⏭️  déjà traité — skip
#   [Batch 573/4119] ⏭️  déjà traité — skip
#   [Batch 574/4119] ⏭️  déjà traité — skip
#   [Batch 575/4119] ⏭️  déjà traité — skip
#   [Batch 576/4119] ⏭️  déjà traité — skip
#   [Batch 577/4119] ⏭️  déjà traité — skip
#   [Batch 578/4119] ⏭️  déjà traité — skip
#   [Batch 579/4119] ⏭️  déjà traité — skip
#   [Batch 580/4119] ⏭️  déjà traité — skip
#   [Batch 581/4119] ⏭️  déjà traité — skip
#   [Batch 582/4119] ⏭️  déjà traité — skip
#   [Batch 583/4119] ⏭️  déjà traité — skip
#   [Batch 584/4119] ⏭️  déjà traité — skip
#   [Batch 585/4119] ⏭️  déjà traité — skip
#   [Batch 586/4119] ⏭️  déjà traité — skip
#   [Batch 587/4119] ⏭️  déjà traité — skip
#   [Batch 588/4119] ⏭️  déjà traité — skip
#   [Batch 589/4119] ⏭️  déjà traité — skip
#   [Batch 590/4119] ⏭️  déjà traité — skip
#   [Batch 591/4119] ⏭️  déjà traité — skip
#   [Batch 592/4119] ⏭️  déjà traité — skip
#   [Batch 593/4119] ⏭️  déjà traité — skip
#   [Batch 594/4119] ⏭️  déjà traité — skip
#   [Batch 595/4119] ⏭️  déjà traité — skip
#   [Batch 596/4119] ⏭️  déjà traité — skip
#   [Batch 597/4119] ⏭️  déjà traité — skip
#   [Batch 598/4119] ⏭️  déjà traité — skip
#   [Batch 599/4119] ⏭️  déjà traité — skip
#   [Batch 600/4119] ⏭️  déjà traité — skip
#   [Batch 601/4119] ⏭️  déjà traité — skip
#   [Batch 602/4119] ⏭️  déjà traité — skip
#   [Batch 603/4119] ⏭️  déjà traité — skip
#   [Batch 604/4119] ⏭️  déjà traité — skip
#   [Batch 605/4119] ⏭️  déjà traité — skip
#   [Batch 606/4119] ⏭️  déjà traité — skip
#   [Batch 607/4119] ⏭️  déjà traité — skip
#   [Batch 608/4119] ⏭️  déjà traité — skip
#   [Batch 609/4119] ⏭️  déjà traité — skip
#   [Batch 610/4119] ⏭️  déjà traité — skip
#   [Batch 611/4119] ⏭️  déjà traité — skip
#   [Batch 612/4119] ⏭️  déjà traité — skip
#   [Batch 613/4119] ⏭️  déjà traité — skip
#   [Batch 614/4119] ⏭️  déjà traité — skip
#   [Batch 615/4119] ⏭️  déjà traité — skip
#   [Batch 616/4119] ⏭️  déjà traité — skip
#   [Batch 617/4119] ⏭️  déjà traité — skip
#   [Batch 618/4119] ⏭️  déjà traité — skip
#   [Batch 619/4119] ⏭️  déjà traité — skip
#   [Batch 620/4119] ⏭️  déjà traité — skip
#   [Batch 621/4119] ⏭️  déjà traité — skip
#   [Batch 622/4119] ⏭️  déjà traité — skip
#   [Batch 623/4119] ⏭️  déjà traité — skip
#   [Batch 624/4119] ⏭️  déjà traité — skip
#   [Batch 625/4119] ⏭️  déjà traité — skip
#   [Batch 626/4119] ⏭️  déjà traité — skip
#   [Batch 627/4119] ⏭️  déjà traité — skip
#   [Batch 628/4119] ⏭️  déjà traité — skip
#   [Batch 629/4119] ⏭️  déjà traité — skip
#   [Batch 630/4119] ⏭️  déjà traité — skip
#   [Batch 631/4119] ⏭️  déjà traité — skip
#   [Batch 632/4119] ⏭️  déjà traité — skip
#   [Batch 633/4119] ⏭️  déjà traité — skip
#   [Batch 634/4119] ⏭️  déjà traité — skip
#   [Batch 635/4119] ⏭️  déjà traité — skip
#   [Batch 636/4119] ⏭️  déjà traité — skip
#   [Batch 637/4119] ⏭️  déjà traité — skip
#   [Batch 638/4119] ⏭️  déjà traité — skip
#   [Batch 639/4119] ⏭️  déjà traité — skip
#   [Batch 640/4119] ⏭️  déjà traité — skip
#   [Batch 641/4119] ⏭️  déjà traité — skip
#   [Batch 642/4119] ⏭️  déjà traité — skip
#   [Batch 643/4119] ⏭️  déjà traité — skip
#   [Batch 644/4119] ⏭️  déjà traité — skip
#   [Batch 645/4119] ⏭️  déjà traité — skip
#   [Batch 646/4119] ⏭️  déjà traité — skip
#   [Batch 647/4119] ⏭️  déjà traité — skip
#   [Batch 648/4119] ⏭️  déjà traité — skip
#   [Batch 649/4119] ⏭️  déjà traité — skip
#   [Batch 650/4119] ⏭️  déjà traité — skip
#   [Batch 651/4119] ⏭️  déjà traité — skip
#   [Batch 652/4119] ⏭️  déjà traité — skip
#   [Batch 653/4119] ⏭️  déjà traité — skip
#   [Batch 654/4119] ⏭️  déjà traité — skip
#   [Batch 655/4119] ⏭️  déjà traité — skip
#   [Batch 656/4119] ⏭️  déjà traité — skip
#   [Batch 657/4119] ⏭️  déjà traité — skip
#   [Batch 658/4119] ⏭️  déjà traité — skip
#   [Batch 659/4119] ⏭️  déjà traité — skip
#   [Batch 660/4119] ⏭️  déjà traité — skip
#   [Batch 661/4119] ⏭️  déjà traité — skip
#   [Batch 662/4119] ⏭️  déjà traité — skip
#   [Batch 663/4119] ⏭️  déjà traité — skip
#   [Batch 664/4119] ⏭️  déjà traité — skip
#   [Batch 665/4119] ⏭️  déjà traité — skip
#   [Batch 666/4119] ⏭️  déjà traité — skip
#   [Batch 667/4119] ⏭️  déjà traité — skip
#   [Batch 668/4119] ⏭️  déjà traité — skip
#   [Batch 669/4119] ⏭️  déjà traité — skip
#   [Batch 670/4119] ⏭️  déjà traité — skip
#   [Batch 671/4119] ⏭️  déjà traité — skip
#   [Batch 672/4119] ⏭️  déjà traité — skip
#   [Batch 673/4119] ⏭️  déjà traité — skip
#   [Batch 674/4119] ⏭️  déjà traité — skip
#   [Batch 675/4119] ⏭️  déjà traité — skip
#   [Batch 676/4119] ⏭️  déjà traité — skip
#   [Batch 677/4119] ⏭️  déjà traité — skip
#   [Batch 678/4119] ⏭️  déjà traité — skip
#   [Batch 679/4119] ⏭️  déjà traité — skip
#   [Batch 680/4119] ⏭️  déjà traité — skip
#   [Batch 681/4119] ⏭️  déjà traité — skip
#   [Batch 682/4119] ⏭️  déjà traité — skip
#   [Batch 683/4119] ⏭️  déjà traité — skip
#   [Batch 684/4119] ⏭️  déjà traité — skip
#   [Batch 685/4119] ⏭️  déjà traité — skip
#   [Batch 686/4119] ⏭️  déjà traité — skip
#   [Batch 687/4119] ⏭️  déjà traité — skip
#   [Batch 688/4119] ⏭️  déjà traité — skip
#   [Batch 689/4119] ⏭️  déjà traité — skip
#   [Batch 690/4119] ⏭️  déjà traité — skip
#   [Batch 691/4119] ⏭️  déjà traité — skip
#   [Batch 692/4119] ⏭️  déjà traité — skip
#   [Batch 693/4119] ⏭️  déjà traité — skip
#   [Batch 694/4119] ⏭️  déjà traité — skip
#   [Batch 695/4119] ⏭️  déjà traité — skip
#   [Batch 696/4119] ⏭️  déjà traité — skip
#   [Batch 697/4119] ⏭️  déjà traité — skip
#   [Batch 698/4119] ⏭️  déjà traité — skip
#   [Batch 699/4119] ⏭️  déjà traité — skip
#   [Batch 700/4119] ⏭️  déjà traité — skip
#   [Batch 701/4119] ⏭️  déjà traité — skip
#   [Batch 702/4119] ⏭️  déjà traité — skip
#   [Batch 703/4119] ⏭️  déjà traité — skip
#   [Batch 704/4119] ⏭️  déjà traité — skip
#   [Batch 705/4119] ⏭️  déjà traité — skip
#   [Batch 706/4119] ⏭️  déjà traité — skip
#   [Batch 707/4119] ⏭️  déjà traité — skip
#   [Batch 708/4119] ⏭️  déjà traité — skip
#   [Batch 709/4119] ⏭️  déjà traité — skip
#   [Batch 710/4119] ⏭️  déjà traité — skip
#   [Batch 711/4119] ⏭️  déjà traité — skip
#   [Batch 712/4119] ⏭️  déjà traité — skip
#   [Batch 713/4119] ⏭️  déjà traité — skip
#   [Batch 714/4119] ⏭️  déjà traité — skip
#   [Batch 715/4119] ⏭️  déjà traité — skip
#   [Batch 716/4119] ⏭️  déjà traité — skip
#   [Batch 717/4119] ⏭️  déjà traité — skip
#   [Batch 718/4119] ⏭️  déjà traité — skip
#   [Batch 719/4119] ⏭️  déjà traité — skip
#   [Batch 720/4119] ⏭️  déjà traité — skip
#   [Batch 721/4119] ⏭️  déjà traité — skip
#   [Batch 722/4119] ⏭️  déjà traité — skip
#   [Batch 723/4119] ⏭️  déjà traité — skip
#   [Batch 724/4119] ⏭️  déjà traité — skip
#   [Batch 725/4119] ⏭️  déjà traité — skip
#   [Batch 726/4119] ⏭️  déjà traité — skip
#   [Batch 727/4119] ⏭️  déjà traité — skip
#   [Batch 728/4119] ⏭️  déjà traité — skip
#   [Batch 729/4119] ⏭️  déjà traité — skip
#   [Batch 730/4119] ⏭️  déjà traité — skip
#   [Batch 731/4119] ⏭️  déjà traité — skip
#   [Batch 732/4119] ⏭️  déjà traité — skip
#   [Batch 733/4119] ⏭️  déjà traité — skip
#   [Batch 734/4119] ⏭️  déjà traité — skip
#   [Batch 735/4119] ⏭️  déjà traité — skip
#   [Batch 736/4119] ⏭️  déjà traité — skip
#   [Batch 737/4119] ⏭️  déjà traité — skip
#   [Batch 738/4119] ⏭️  déjà traité — skip
#   [Batch 739/4119] ⏭️  déjà traité — skip
#   [Batch 740/4119] ⏭️  déjà traité — skip
#   [Batch 741/4119] ⏭️  déjà traité — skip
#   [Batch 742/4119] ⏭️  déjà traité — skip
#   [Batch 743/4119] ⏭️  déjà traité — skip
#   [Batch 744/4119] ⏭️  déjà traité — skip
#   [Batch 745/4119] ⏭️  déjà traité — skip
#   [Batch 746/4119] ⏭️  déjà traité — skip
#   [Batch 747/4119] ⏭️  déjà traité — skip
#   [Batch 748/4119] ⏭️  déjà traité — skip
#   [Batch 749/4119] ⏭️  déjà traité — skip
#   [Batch 750/4119] ⏭️  déjà traité — skip
#   [Batch 751/4119] ⏭️  déjà traité — skip
#   [Batch 752/4119] ⏭️  déjà traité — skip
#   [Batch 753/4119] ⏭️  déjà traité — skip
#   [Batch 754/4119] ⏭️  déjà traité — skip
#   [Batch 755/4119] ⏭️  déjà traité — skip
#   [Batch 756/4119] ⏭️  déjà traité — skip
#   [Batch 757/4119] ⏭️  déjà traité — skip
#   [Batch 758/4119] ⏭️  déjà traité — skip
#   [Batch 759/4119] ⏭️  déjà traité — skip
#   [Batch 760/4119] ⏭️  déjà traité — skip
#   [Batch 761/4119] ⏭️  déjà traité — skip
#   [Batch 762/4119] ⏭️  déjà traité — skip
#   [Batch 763/4119] ⏭️  déjà traité — skip
#   [Batch 764/4119] ⏭️  déjà traité — skip
#   [Batch 765/4119] ⏭️  déjà traité — skip
#   [Batch 766/4119] ⏭️  déjà traité — skip
#   [Batch 767/4119] ⏭️  déjà traité — skip
#   [Batch 768/4119] ⏭️  déjà traité — skip
#   [Batch 769/4119] ⏭️  déjà traité — skip
#   [Batch 770/4119] ⏭️  déjà traité — skip
#   [Batch 771/4119] ⏭️  déjà traité — skip
#   [Batch 772/4119] ⏭️  déjà traité — skip
#   [Batch 773/4119] ⏭️  déjà traité — skip
#   [Batch 774/4119] ⏭️  déjà traité — skip
#   [Batch 775/4119] ⏭️  déjà traité — skip
#   [Batch 776/4119] ⏭️  déjà traité — skip
#   [Batch 777/4119] ⏭️  déjà traité — skip
#   [Batch 778/4119] ⏭️  déjà traité — skip
#   [Batch 779/4119] ⏭️  déjà traité — skip
#   [Batch 780/4119] ⏭️  déjà traité — skip
#   [Batch 781/4119] ⏭️  déjà traité — skip
#   [Batch 782/4119] ⏭️  déjà traité — skip
#   [Batch 783/4119] ⏭️  déjà traité — skip
#   [Batch 784/4119] ⏭️  déjà traité — skip
#   [Batch 785/4119] ⏭️  déjà traité — skip
#   [Batch 786/4119] ⏭️  déjà traité — skip
#   [Batch 787/4119] ⏭️  déjà traité — skip
#   [Batch 788/4119] ⏭️  déjà traité — skip
#   [Batch 789/4119] ⏭️  déjà traité — skip
#   [Batch 790/4119] ⏭️  déjà traité — skip
#   [Batch 791/4119] ⏭️  déjà traité — skip
#   [Batch 792/4119] ⏭️  déjà traité — skip
#   [Batch 793/4119] ⏭️  déjà traité — skip
#   [Batch 794/4119] ⏭️  déjà traité — skip
#   [Batch 795/4119] ⏭️  déjà traité — skip
#   [Batch 796/4119] ⏭️  déjà traité — skip
#   [Batch 797/4119] ⏭️  déjà traité — skip
#   [Batch 798/4119] ⏭️  déjà traité — skip
#   [Batch 799/4119] ⏭️  déjà traité — skip
#   [Batch 800/4119] ⏭️  déjà traité — skip
#   [Batch 801/4119] ⏭️  déjà traité — skip
#   [Batch 802/4119] ⏭️  déjà traité — skip
#   [Batch 803/4119] ⏭️  déjà traité — skip
#   [Batch 804/4119] ⏭️  déjà traité — skip
#   [Batch 805/4119] ⏭️  déjà traité — skip
#   [Batch 806/4119] ⏭️  déjà traité — skip
#   [Batch 807/4119] ⏭️  déjà traité — skip
#   [Batch 808/4119] ⏭️  déjà traité — skip
#   [Batch 809/4119] ⏭️  déjà traité — skip
#   [Batch 810/4119] ⏭️  déjà traité — skip
#   [Batch 811/4119] ⏭️  déjà traité — skip
#   [Batch 812/4119] ⏭️  déjà traité — skip
#   [Batch 813/4119] ⏭️  déjà traité — skip
#   [Batch 814/4119] ⏭️  déjà traité — skip
#   [Batch 815/4119] ⏭️  déjà traité — skip
#   [Batch 816/4119] ⏭️  déjà traité — skip
#   [Batch 817/4119] ⏭️  déjà traité — skip
#   [Batch 818/4119] ⏭️  déjà traité — skip
#   [Batch 819/4119] ⏭️  déjà traité — skip
#   [Batch 820/4119] ⏭️  déjà traité — skip
#   [Batch 821/4119] ⏭️  déjà traité — skip
#   [Batch 822/4119] ⏭️  déjà traité — skip
#   [Batch 823/4119] ⏭️  déjà traité — skip
#   [Batch 824/4119] ⏭️  déjà traité — skip
#   [Batch 825/4119] ⏭️  déjà traité — skip
#   [Batch 826/4119] ⏭️  déjà traité — skip
#   [Batch 827/4119] ⏭️  déjà traité — skip
#   [Batch 828/4119] ⏭️  déjà traité — skip
#   [Batch 829/4119] ⏭️  déjà traité — skip
#   [Batch 830/4119] ⏭️  déjà traité — skip
#   [Batch 831/4119] ⏭️  déjà traité — skip
#   [Batch 832/4119] ⏭️  déjà traité — skip
#   [Batch 833/4119] ⏭️  déjà traité — skip
#   [Batch 834/4119] ⏭️  déjà traité — skip
#   [Batch 835/4119] ⏭️  déjà traité — skip
#   [Batch 836/4119] ⏭️  déjà traité — skip
#   [Batch 837/4119] ⏭️  déjà traité — skip
#   [Batch 838/4119] ⏭️  déjà traité — skip
#   [Batch 839/4119] ⏭️  déjà traité — skip
#   [Batch 840/4119] ⏭️  déjà traité — skip
#   [Batch 841/4119] ⏭️  déjà traité — skip
#   [Batch 842/4119] ⏭️  déjà traité — skip
#   [Batch 843/4119] ⏭️  déjà traité — skip
#   [Batch 844/4119] ⏭️  déjà traité — skip
#   [Batch 845/4119] ⏭️  déjà traité — skip
#   [Batch 846/4119] ⏭️  déjà traité — skip
#   [Batch 847/4119] ⏭️  déjà traité — skip
#   [Batch 848/4119] ⏭️  déjà traité — skip
#   [Batch 849/4119] ⏭️  déjà traité — skip
#   [Batch 850/4119] ⏭️  déjà traité — skip
#   [Batch 851/4119] ⏭️  déjà traité — skip
#   [Batch 852/4119] ⏭️  déjà traité — skip
#   [Batch 853/4119] ⏭️  déjà traité — skip
#   [Batch 854/4119] ⏭️  déjà traité — skip
#   [Batch 855/4119] ⏭️  déjà traité — skip
#   [Batch 856/4119] ⏭️  déjà traité — skip
#   [Batch 857/4119] ⏭️  déjà traité — skip
#   [Batch 858/4119] ⏭️  déjà traité — skip
#   [Batch 859/4119] ⏭️  déjà traité — skip
#   [Batch 860/4119] ⏭️  déjà traité — skip
#   [Batch 861/4119] ⏭️  déjà traité — skip
#   [Batch 862/4119] ⏭️  déjà traité — skip
#   [Batch 863/4119] ⏭️  déjà traité — skip
#   [Batch 864/4119] ⏭️  déjà traité — skip
#   [Batch 865/4119] ⏭️  déjà traité — skip
#   [Batch 866/4119] ⏭️  déjà traité — skip
#   [Batch 867/4119] ⏭️  déjà traité — skip
#   [Batch 868/4119] ⏭️  déjà traité — skip
#   [Batch 869/4119] ⏭️  déjà traité — skip
#   [Batch 870/4119] ⏭️  déjà traité — skip
#   [Batch 871/4119] ⏭️  déjà traité — skip
#   [Batch 872/4119] ⏭️  déjà traité — skip
#   [Batch 873/4119] ⏭️  déjà traité — skip
#   [Batch 874/4119] ⏭️  déjà traité — skip
#   [Batch 875/4119] ⏭️  déjà traité — skip
#   [Batch 876/4119] ⏭️  déjà traité — skip
#   [Batch 877/4119] ⏭️  déjà traité — skip
#   [Batch 878/4119] ⏭️  déjà traité — skip
#   [Batch 879/4119] ⏭️  déjà traité — skip
#   [Batch 880/4119] ⏭️  déjà traité — skip
#   [Batch 881/4119] ⏭️  déjà traité — skip
#   [Batch 882/4119] ⏭️  déjà traité — skip
#   [Batch 883/4119] ⏭️  déjà traité — skip
#   [Batch 884/4119] ⏭️  déjà traité — skip
#   [Batch 885/4119] ⏭️  déjà traité — skip
#   [Batch 886/4119] ⏭️  déjà traité — skip
#   [Batch 887/4119] ⏭️  déjà traité — skip
#   [Batch 888/4119] ⏭️  déjà traité — skip
#   [Batch 889/4119] ⏭️  déjà traité — skip
#   [Batch 890/4119] ⏭️  déjà traité — skip
#   [Batch 891/4119] ⏭️  déjà traité — skip
#   [Batch 892/4119] ⏭️  déjà traité — skip
#   [Batch 893/4119] ⏭️  déjà traité — skip
#   [Batch 894/4119] ⏭️  déjà traité — skip
#   [Batch 895/4119] ⏭️  déjà traité — skip
#   [Batch 896/4119] ⏭️  déjà traité — skip
#   [Batch 897/4119] ⏭️  déjà traité — skip
#   [Batch 898/4119] ⏭️  déjà traité — skip
#   [Batch 899/4119] ⏭️  déjà traité — skip
#   [Batch 900/4119] ⏭️  déjà traité — skip
#   [Batch 901/4119] ⏭️  déjà traité — skip
#   [Batch 902/4119] ⏭️  déjà traité — skip
#   [Batch 903/4119] ⏭️  déjà traité — skip
#   [Batch 904/4119] ⏭️  déjà traité — skip
#   [Batch 905/4119] ⏭️  déjà traité — skip
#   [Batch 906/4119] ⏭️  déjà traité — skip
#   [Batch 907/4119] ⏭️  déjà traité — skip
#   [Batch 908/4119] ⏭️  déjà traité — skip
#   [Batch 909/4119] ⏭️  déjà traité — skip
#   [Batch 910/4119] ⏭️  déjà traité — skip
#   [Batch 911/4119] ⏭️  déjà traité — skip
#   [Batch 912/4119] ⏭️  déjà traité — skip
#   [Batch 913/4119] ⏭️  déjà traité — skip
#   [Batch 914/4119] ⏭️  déjà traité — skip
#   [Batch 915/4119] ⏭️  déjà traité — skip
#   [Batch 916/4119] ⏭️  déjà traité — skip
#   [Batch 917/4119] ⏭️  déjà traité — skip
#   [Batch 918/4119] ⏭️  déjà traité — skip
#   [Batch 919/4119] ⏭️  déjà traité — skip
#   [Batch 920/4119] ⏭️  déjà traité — skip
#   [Batch 921/4119] ⏭️  déjà traité — skip
#   [Batch 922/4119] ⏭️  déjà traité — skip
#   [Batch 923/4119] ⏭️  déjà traité — skip
#   [Batch 924/4119] ⏭️  déjà traité — skip
#   [Batch 925/4119] ⏭️  déjà traité — skip
#   [Batch 926/4119] ⏭️  déjà traité — skip
#   [Batch 927/4119] ⏭️  déjà traité — skip
#   [Batch 928/4119] ⏭️  déjà traité — skip
#   [Batch 929/4119] ⏭️  déjà traité — skip
#   [Batch 930/4119] ⏭️  déjà traité — skip
#   [Batch 931/4119] ⏭️  déjà traité — skip
#   [Batch 932/4119] ⏭️  déjà traité — skip
#   [Batch 933/4119] ⏭️  déjà traité — skip
#   [Batch 934/4119] ⏭️  déjà traité — skip
#   [Batch 935/4119] ⏭️  déjà traité — skip
#   [Batch 936/4119] ⏭️  déjà traité — skip
#   [Batch 937/4119] ⏭️  déjà traité — skip
#   [Batch 938/4119] ⏭️  déjà traité — skip
#   [Batch 939/4119] ⏭️  déjà traité — skip
#   [Batch 940/4119] ⏭️  déjà traité — skip
#   [Batch 941/4119] ⏭️  déjà traité — skip
#   [Batch 942/4119] ⏭️  déjà traité — skip
#   [Batch 943/4119] ⏭️  déjà traité — skip
#   [Batch 944/4119] ⏭️  déjà traité — skip
#   [Batch 945/4119] ⏭️  déjà traité — skip
#   [Batch 946/4119] ⏭️  déjà traité — skip
#   [Batch 947/4119] ⏭️  déjà traité — skip
#   [Batch 948/4119] ⏭️  déjà traité — skip
#   [Batch 949/4119] ⏭️  déjà traité — skip
#   [Batch 950/4119] ⏭️  déjà traité — skip
#   [Batch 951/4119] ⏭️  déjà traité — skip
#   [Batch 952/4119] ⏭️  déjà traité — skip
#   [Batch 953/4119] ⏭️  déjà traité — skip
#   [Batch 954/4119] ⏭️  déjà traité — skip
#   [Batch 955/4119] ⏭️  déjà traité — skip
#   [Batch 956/4119] ⏭️  déjà traité — skip
#   [Batch 957/4119] ⏭️  déjà traité — skip
#   [Batch 958/4119] ⏭️  déjà traité — skip
#   [Batch 959/4119] ⏭️  déjà traité — skip
#   [Batch 960/4119] ⏭️  déjà traité — skip
#   [Batch 961/4119] ⏭️  déjà traité — skip
#   [Batch 962/4119] ⏭️  déjà traité — skip
#   [Batch 963/4119] ⏭️  déjà traité — skip
#   [Batch 964/4119] ⏭️  déjà traité — skip
#   [Batch 965/4119] ⏭️  déjà traité — skip
#   [Batch 966/4119] ⏭️  déjà traité — skip
#   [Batch 967/4119] ⏭️  déjà traité — skip
#   [Batch 968/4119] ⏭️  déjà traité — skip
#   [Batch 969/4119] ⏭️  déjà traité — skip
#   [Batch 970/4119] ⏭️  déjà traité — skip
#   [Batch 971/4119] ⏭️  déjà traité — skip
#   [Batch 972/4119] ⏭️  déjà traité — skip
#   [Batch 973/4119] ⏭️  déjà traité — skip
#   [Batch 974/4119] ⏭️  déjà traité — skip
#   [Batch 975/4119] ⏭️  déjà traité — skip
#   [Batch 976/4119] ⏭️  déjà traité — skip
#   [Batch 977/4119] ⏭️  déjà traité — skip
#   [Batch 978/4119] ⏭️  déjà traité — skip
#   [Batch 979/4119] ⏭️  déjà traité — skip
#   [Batch 980/4119] ⏭️  déjà traité — skip
#   [Batch 981/4119] ⏭️  déjà traité — skip
#   [Batch 982/4119] ⏭️  déjà traité — skip
#   [Batch 983/4119] ⏭️  déjà traité — skip
#   [Batch 984/4119] ⏭️  déjà traité — skip
#   [Batch 985/4119] ⏭️  déjà traité — skip
#   [Batch 986/4119] ⏭️  déjà traité — skip
#   [Batch 987/4119] ⏭️  déjà traité — skip
#   [Batch 988/4119] ⏭️  déjà traité — skip
#   [Batch 989/4119] ⏭️  déjà traité — skip
#   [Batch 990/4119] ⏭️  déjà traité — skip
#   [Batch 991/4119] ⏭️  déjà traité — skip
#   [Batch 992/4119] ⏭️  déjà traité — skip
#   [Batch 993/4119] ⏭️  déjà traité — skip
#   [Batch 994/4119] ⏭️  déjà traité — skip
#   [Batch 995/4119] ⏭️  déjà traité — skip
#   [Batch 996/4119] ⏭️  déjà traité — skip
#   [Batch 997/4119] ⏭️  déjà traité — skip
#   [Batch 998/4119] ⏭️  déjà traité — skip
#   [Batch 999/4119] ⏭️  déjà traité — skip
#   [Batch 1000/4119] ⏭️  déjà traité — skip
#   [Batch 1001/4119] ⏭️  déjà traité — skip
#   [Batch 1002/4119] ⏭️  déjà traité — skip
#   [Batch 1003/4119] ⏭️  déjà traité — skip
#   [Batch 1004/4119] ⏭️  déjà traité — skip
#   [Batch 1005/4119] ⏭️  déjà traité — skip
#   [Batch 1006/4119] ⏭️  déjà traité — skip
#   [Batch 1007/4119] ⏭️  déjà traité — skip
#   [Batch 1008/4119] ⏭️  déjà traité — skip
#   [Batch 1009/4119] ⏭️  déjà traité — skip
#   [Batch 1010/4119] ⏭️  déjà traité — skip
#   [Batch 1011/4119] ⏭️  déjà traité — skip
#   [Batch 1012/4119] ⏭️  déjà traité — skip
#   [Batch 1013/4119] ⏭️  déjà traité — skip
#   [Batch 1014/4119] ⏭️  déjà traité — skip
#   [Batch 1015/4119] ⏭️  déjà traité — skip
#   [Batch 1016/4119] ⏭️  déjà traité — skip
#   [Batch 1017/4119] ⏭️  déjà traité — skip
#   [Batch 1018/4119] ⏭️  déjà traité — skip
#   [Batch 1019/4119] ⏭️  déjà traité — skip
#   [Batch 1020/4119] ⏭️  déjà traité — skip
#   [Batch 1021/4119] ⏭️  déjà traité — skip
#   [Batch 1022/4119] ⏭️  déjà traité — skip
#   [Batch 1023/4119] ⏭️  déjà traité — skip
#   [Batch 1024/4119] ⏭️  déjà traité — skip
#   [Batch 1025/4119] ⏭️  déjà traité — skip
#   [Batch 1026/4119] ⏭️  déjà traité — skip
#   [Batch 1027/4119] ⏭️  déjà traité — skip
#   [Batch 1028/4119] ⏭️  déjà traité — skip
#   [Batch 1029/4119] ⏭️  déjà traité — skip
#   [Batch 1030/4119] ⏭️  déjà traité — skip
#   [Batch 1031/4119] ⏭️  déjà traité — skip
#   [Batch 1032/4119] ⏭️  déjà traité — skip
#   [Batch 1033/4119] ⏭️  déjà traité — skip
#   [Batch 1034/4119] ⏭️  déjà traité — skip
#   [Batch 1035/4119] ⏭️  déjà traité — skip
#   [Batch 1036/4119] ⏭️  déjà traité — skip
#   [Batch 1037/4119] ⏭️  déjà traité — skip
#   [Batch 1038/4119] ⏭️  déjà traité — skip
#   [Batch 1039/4119] ⏭️  déjà traité — skip
#   [Batch 1040/4119] ⏭️  déjà traité — skip
#   [Batch 1041/4119] ⏭️  déjà traité — skip
#   [Batch 1042/4119] ⏭️  déjà traité — skip
#   [Batch 1043/4119] ⏭️  déjà traité — skip
#   [Batch 1044/4119] ⏭️  déjà traité — skip
#   [Batch 1045/4119] ⏭️  déjà traité — skip
#   [Batch 1046/4119] ⏭️  déjà traité — skip
#   [Batch 1047/4119] ⏭️  déjà traité — skip
#   [Batch 1048/4119] ⏭️  déjà traité — skip
#   [Batch 1049/4119] ⏭️  déjà traité — skip
#   [Batch 1050/4119] ⏭️  déjà traité — skip
#   [Batch 1051/4119] ⏭️  déjà traité — skip
#   [Batch 1052/4119] ⏭️  déjà traité — skip
#   [Batch 1053/4119] ⏭️  déjà traité — skip
#   [Batch 1054/4119] ⏭️  déjà traité — skip
#   [Batch 1055/4119] ⏭️  déjà traité — skip
#   [Batch 1056/4119] ⏭️  déjà traité — skip
#   [Batch 1057/4119] ⏭️  déjà traité — skip
#   [Batch 1058/4119] ⏭️  déjà traité — skip
#   [Batch 1059/4119] ⏭️  déjà traité — skip
#   [Batch 1060/4119] ⏭️  déjà traité — skip
#   [Batch 1061/4119] ⏭️  déjà traité — skip
#   [Batch 1062/4119] ⏭️  déjà traité — skip
#   [Batch 1063/4119] ⏭️  déjà traité — skip
#   [Batch 1064/4119] ⏭️  déjà traité — skip
#   [Batch 1065/4119] ⏭️  déjà traité — skip
#   [Batch 1066/4119] ⏭️  déjà traité — skip
#   [Batch 1067/4119] ⏭️  déjà traité — skip
#   [Batch 1068/4119] ⏭️  déjà traité — skip
#   [Batch 1069/4119] ⏭️  déjà traité — skip
#   [Batch 1070/4119] ⏭️  déjà traité — skip
#   [Batch 1071/4119] ⏭️  déjà traité — skip
#   [Batch 1072/4119] ⏭️  déjà traité — skip
#   [Batch 1073/4119] ⏭️  déjà traité — skip
#   [Batch 1074/4119] ⏭️  déjà traité — skip
#   [Batch 1075/4119] ⏭️  déjà traité — skip
#   [Batch 1076/4119] ⏭️  déjà traité — skip
#   [Batch 1077/4119] ⏭️  déjà traité — skip
#   [Batch 1078/4119] ⏭️  déjà traité — skip
#   [Batch 1079/4119] ⏭️  déjà traité — skip
#   [Batch 1080/4119] ⏭️  déjà traité — skip
#   [Batch 1081/4119] ⏭️  déjà traité — skip
#   [Batch 1082/4119] ⏭️  déjà traité — skip
#   [Batch 1083/4119] ⏭️  déjà traité — skip
#   [Batch 1084/4119] ⏭️  déjà traité — skip
#   [Batch 1085/4119] ⏭️  déjà traité — skip
#   [Batch 1086/4119] ⏭️  déjà traité — skip
#   [Batch 1087/4119] ⏭️  déjà traité — skip
#   [Batch 1088/4119] ⏭️  déjà traité — skip
#   [Batch 1089/4119] ⏭️  déjà traité — skip
#   [Batch 1090/4119] ⏭️  déjà traité — skip
#   [Batch 1091/4119] ⏭️  déjà traité — skip
#   [Batch 1092/4119] ⏭️  déjà traité — skip
#   [Batch 1093/4119] ⏭️  déjà traité — skip
#   [Batch 1094/4119] ⏭️  déjà traité — skip
#   [Batch 1095/4119] ⏭️  déjà traité — skip
#   [Batch 1096/4119] ⏭️  déjà traité — skip
#   [Batch 1097/4119] ⏭️  déjà traité — skip
#   [Batch 1098/4119] ⏭️  déjà traité — skip
#   [Batch 1099/4119] ⏭️  déjà traité — skip
#   [Batch 1100/4119] ⏭️  déjà traité — skip
#   [Batch 1101/4119] ⏭️  déjà traité — skip
#   [Batch 1102/4119] ⏭️  déjà traité — skip
#   [Batch 1103/4119] ⏭️  déjà traité — skip
#   [Batch 1104/4119] ⏭️  déjà traité — skip
#   [Batch 1105/4119] ⏭️  déjà traité — skip
#   [Batch 1106/4119] ⏭️  déjà traité — skip
#   [Batch 1107/4119] ⏭️  déjà traité — skip
#   [Batch 1108/4119] ⏭️  déjà traité — skip
#   [Batch 1109/4119] ⏭️  déjà traité — skip
#   [Batch 1110/4119] ⏭️  déjà traité — skip
#   [Batch 1111/4119] ⏭️  déjà traité — skip
#   [Batch 1112/4119] ⏭️  déjà traité — skip
#   [Batch 1113/4119] ⏭️  déjà traité — skip
#   [Batch 1114/4119] ⏭️  déjà traité — skip
#   [Batch 1115/4119] ⏭️  déjà traité — skip
#   [Batch 1116/4119] ⏭️  déjà traité — skip
#   [Batch 1117/4119] ⏭️  déjà traité — skip
#   [Batch 1118/4119] ⏭️  déjà traité — skip
# ...
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\contextlib.py:131, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     130 try:
# --> 131     self.gen.throw(type, value, traceback)
#     132 except StopIteration as exc:
#     133     # Suppress StopIteration *unless* it's the same exception that
#     134     # was passed to throw().  This prevents a StopIteration
#     135     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       1 if __name__ == "__main__":
#       2
#       3     #exécuteur 1 → df_all.iloc[0:205944]
#    (...)
#       6     # Exécuteur 4 → df_all.iloc[617832:823776]
#       7     # Exécuteur 5 → df_all.iloc[823776:1029720]
# ----> 9     df, metadata = classify_recipes_pipeline(
#      10          titles_source= recipe.iloc[411888:617832],
#      11          ingredients_source= ingredients,
#      12          subset="3",
#      13          api_key= OPENROUTER_API_KEY,
#      14          model_name= MODEL_NAME,
#      15          output_dir= DATA_DIR/"recipes_family",
#      16      )
#      18     # ── Charger les résultats plus tard ─────────────────────────
#      19     # df = load_classification_results("./output_classification/recipe_classifications_subset1_XXXX.csv")
#      20     # pates = get_recipes_by_family(df, "PATES")
#      21     # pates_soupe = get_recipes_by_family(df, "PATES", type_plat="SOUPE")
#      22     # na_recettes = get_na_recipes(df)
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:714, in classify_recipes_pipeline(titles_source, ingredients_source, sqlite_table, api_key, model_name, subset, batch_size, pause_10, pause_50, max_retries, retry_delay_m, output_dir, save_intermediary, save_every_n_batches)
#     710     continue
#     712 print(f"  [Batch {batch_idx+1}/{total_batches_p2}] recettes {start+1}–{end}... ", end="", flush=True)
# --> 714 response = call_llm_recursive(
#     715     client, model_name,
#     716     SYSTEM_PROMPT, batch,
#     717     pass_number=2,
#     718     max_retries=max_retries,
#     719     retry_delay_m=retry_delay_m,
#     720     batch_label=f"P2-{batch_idx+1}",
#     721     depth=0,
#     722 )
#     724 valid = 0
#     725 for item in response:
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:456, in call_llm_recursive(client, model_name, system_prompt, batch, pass_number, max_retries, retry_delay_m, batch_label, depth)
#     449 print(f"  {indent}✂️  [{label}] Split → [{len(left)}] + [{len(right)}] (profondeur {depth+1})")
#     451 results_left  = call_llm_recursive(
#     452     client, model_name, system_prompt,
#     453     left,  pass_number, max_retries, retry_delay_m,
#     454     batch_label=f"{batch_label}L", depth=depth + 1,
#     455 )
# --> 456 results_right = call_llm_recursive(
#     457     client, model_name, system_prompt,
#     458     right, pass_number, max_retries, retry_delay_m,
#     459     batch_label=f"{batch_label}R", depth=depth + 1,
#     460 )
#     462 return results_left + results_right
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:456, in call_llm_recursive(client, model_name, system_prompt, batch, pass_number, max_retries, retry_delay_m, batch_label, depth)
#     449 print(f"  {indent}✂️  [{label}] Split → [{len(left)}] + [{len(right)}] (profondeur {depth+1})")
#     451 results_left  = call_llm_recursive(
#     452     client, model_name, system_prompt,
#     453     left,  pass_number, max_retries, retry_delay_m,
#     454     batch_label=f"{batch_label}L", depth=depth + 1,
#     455 )
# --> 456 results_right = call_llm_recursive(
#     457     client, model_name, system_prompt,
#     458     right, pass_number, max_retries, retry_delay_m,
#     459     batch_label=f"{batch_label}R", depth=depth + 1,
#     460 )
#     462 return results_left + results_right
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:451, in call_llm_recursive(client, model_name, system_prompt, batch, pass_number, max_retries, retry_delay_m, batch_label, depth)
#     447 right = batch[mid:]
#     449 print(f"  {indent}✂️  [{label}] Split → [{len(left)}] + [{len(right)}] (profondeur {depth+1})")
# --> 451 results_left  = call_llm_recursive(
#     452     client, model_name, system_prompt,
#     453     left,  pass_number, max_retries, retry_delay_m,
#     454     batch_label=f"{batch_label}L", depth=depth + 1,
#     455 )
#     456 results_right = call_llm_recursive(
#     457     client, model_name, system_prompt,
#     458     right, pass_number, max_retries, retry_delay_m,
#     459     batch_label=f"{batch_label}R", depth=depth + 1,
#     460 )
#     462 return results_left + results_right
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:456, in call_llm_recursive(client, model_name, system_prompt, batch, pass_number, max_retries, retry_delay_m, batch_label, depth)
#     449 print(f"  {indent}✂️  [{label}] Split → [{len(left)}] + [{len(right)}] (profondeur {depth+1})")
#     451 results_left  = call_llm_recursive(
#     452     client, model_name, system_prompt,
#     453     left,  pass_number, max_retries, retry_delay_m,
#     454     batch_label=f"{batch_label}L", depth=depth + 1,
#     455 )
# --> 456 results_right = call_llm_recursive(
#     457     client, model_name, system_prompt,
#     458     right, pass_number, max_retries, retry_delay_m,
#     459     batch_label=f"{batch_label}R", depth=depth + 1,
#     460 )
#     462 return results_left + results_right
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:456, in call_llm_recursive(client, model_name, system_prompt, batch, pass_number, max_retries, retry_delay_m, batch_label, depth)
#     449 print(f"  {indent}✂️  [{label}] Split → [{len(left)}] + [{len(right)}] (profondeur {depth+1})")
#     451 results_left  = call_llm_recursive(
#     452     client, model_name, system_prompt,
#     453     left,  pass_number, max_retries, retry_delay_m,
#     454     batch_label=f"{batch_label}L", depth=depth + 1,
#     455 )
# --> 456 results_right = call_llm_recursive(
#     457     client, model_name, system_prompt,
#     458     right, pass_number, max_retries, retry_delay_m,
#     459     batch_label=f"{batch_label}R", depth=depth + 1,
#     460 )
#     462 return results_left + results_right
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:451, in call_llm_recursive(client, model_name, system_prompt, batch, pass_number, max_retries, retry_delay_m, batch_label, depth)
#     447 right = batch[mid:]
#     449 print(f"  {indent}✂️  [{label}] Split → [{len(left)}] + [{len(right)}] (profondeur {depth+1})")
# --> 451 results_left  = call_llm_recursive(
#     452     client, model_name, system_prompt,
#     453     left,  pass_number, max_retries, retry_delay_m,
#     454     batch_label=f"{batch_label}L", depth=depth + 1,
#     455 )
#     456 results_right = call_llm_recursive(
#     457     client, model_name, system_prompt,
#     458     right, pass_number, max_retries, retry_delay_m,
#     459     batch_label=f"{batch_label}R", depth=depth + 1,
#     460 )
#     462 return results_left + results_right
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:404, in call_llm_recursive(client, model_name, system_prompt, batch, pass_number, max_retries, retry_delay_m, batch_label, depth)
#     401 else:
#     402     prompt = build_prompt_pass2(batch)
# --> 404 result = _call_llm_single(
#     405     client, model_name,
#     406     system_prompt, prompt,
#     407     max_retries, retry_delay_m,
#     408     batch_label=label,
#     409 )
#     411 # ── Succès → validation des IDs ─────────────────────────────
#     412 if result is not None:
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:296, in _call_llm_single(client, model_name, system_prompt, user_prompt, max_retries, retry_delay_m, batch_label)
#     294 for attempt in range(1, max_retries + 1):
#     295     try:
# --> 296         completion = client.chat.completions.create(
#     297             extra_headers={
#     298                 "HTTP-Referer": "recipe_family_classifier",
#     299                 "X-Title": "Recipe Family Classification Pipeline",
#     300             },
#     301             model=model_name,
#     302             temperature=0.1,
#     303             messages=[
#     304                 {"role": "system", "content": system_prompt},
#     305                 {"role": "user",   "content": user_prompt},
#     306             ],
#     307         )
#     309         raw = completion.choices[0].message.content.strip()
#     311         # Nettoyage des balises markdown si présentes
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\resources\chat\completions\completions.py:1131, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1086 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1087 def create(
#    1088     self,
#    (...)
#    1128     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1129 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1130     validate_response_format(response_format)
# -> 1131     return self._post(
#    1132         "/chat/completions",
#    1133         body=maybe_transform(
#    1134             {
#    1135                 "messages": messages,
#    1136                 "model": model,
#    1137                 "audio": audio,
#    1138                 "frequency_penalty": frequency_penalty,
#    1139                 "function_call": function_call,
#    1140                 "functions": functions,
#    1141                 "logit_bias": logit_bias,
#    1142                 "logprobs": logprobs,
#    1143                 "max_completion_tokens": max_completion_tokens,
#    1144                 "max_tokens": max_tokens,
#    1145                 "metadata": metadata,
#    1146                 "modalities": modalities,
#    1147                 "n": n,
#    1148                 "parallel_tool_calls": parallel_tool_calls,
#    1149                 "prediction": prediction,
#    1150                 "presence_penalty": presence_penalty,
#    1151                 "prompt_cache_key": prompt_cache_key,
#    1152                 "reasoning_effort": reasoning_effort,
#    1153                 "response_format": response_format,
#    1154                 "safety_identifier": safety_identifier,
#    1155                 "seed": seed,
#    1156                 "service_tier": service_tier,
#    1157                 "stop": stop,
#    1158                 "store": store,
#    1159                 "stream": stream,
#    1160                 "stream_options": stream_options,
#    1161                 "temperature": temperature,
#    1162                 "tool_choice": tool_choice,
#    1163                 "tools": tools,
#    1164                 "top_logprobs": top_logprobs,
#    1165                 "top_p": top_p,
#    1166                 "user": user,
#    1167                 "web_search_options": web_search_options,
#    1168             },
#    1169             completion_create_params.CompletionCreateParamsStreaming
#    1170             if stream
#    1171             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1172         ),
#    1173         options=make_request_options(
#    1174             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1175         ),
#    1176         cast_to=ChatCompletion,
#    1177         stream=stream or False,
#    1178         stream_cls=Stream[ChatCompletionChunk],
#    1179     )
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\_base_client.py:1002, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     999 log.debug("Encountered Exception", exc_info=True)
#    1001 if remaining_retries > 0:
# -> 1002     self._sleep_for_retry(
#    1003         retries_taken=retries_taken,
#    1004         max_retries=max_retries,
#    1005         options=input_options,
#    1006         response=None,
#    1007     )
#    1008     continue
#    1010 log.debug("Raising connection error")
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient._sleep_for_retry(self, retries_taken, max_retries, options, response)
#    1067 timeout = self._calculate_retry_timeout(remaining_retries, options, response.headers if response else None)
#    1068 log.info("Retrying request to %s in %f seconds", options.url, timeout)
# -> 1070 time.sleep(timeout)
#
# KeyboardInterrupt:
