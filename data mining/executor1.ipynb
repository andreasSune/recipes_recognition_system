# %%
import pandas as pd
from recipe_family_classifier_pipe import *
from dotenv import load_dotenv
import os
from pathlib import Path
# Charger les variables du fichier .env
load_dotenv()
# Out:
# True

# %%
OPENROUTER_API_KEY = os.getenv('OPENROUTER_API_KEY_1')
MODEL_NAME = os.getenv('MODEL_NAME_5')

# %%
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent   
DATA_DIR = PROJECT_ROOT / "data"

# %%
recipe = pd.read_csv(DATA_DIR / "recipes.csv")
ingredients = pd.read_csv(DATA_DIR / "ingredients_with_titles.csv")

# %%
if __name__ == "__main__":

    #exécuteur 1 → df_all.iloc[0:205944]
    # Exécuteur 2 → df_all.iloc[205944:411888]
    # Exécuteur 3 → df_all.iloc[411888:617832]
    # Exécuteur 4 → df_all.iloc[617832:823776]
    # Exécuteur 5 → df_all.iloc[823776:1029720]
  
    df, metadata = classify_recipes_pipeline(
         titles_source= recipe.iloc[0:205944],
         ingredients_source= ingredients,
         subset="1",
         api_key= OPENROUTER_API_KEY,
         model_name= MODEL_NAME,
         output_dir= DATA_DIR/"recipes_family",
     )

    # ── Charger les résultats plus tard ─────────────────────────
    # df = load_classification_results("./output_classification/recipe_classifications_subset1_XXXX.csv")
    # pates = get_recipes_by_family(df, "PATES")
    # pates_soupe = get_recipes_by_family(df, "PATES", type_plat="SOUPE")
    # na_recettes = get_na_recipes(df)
# Out:
# ============================================================
#   PIPELINE DE CLASSIFICATION DES FAMILLES DE RECETTES
#   Laboratoire Liara — UQAC
# ============================================================
#   Subset      : 1
#   Modèle      : openai/gpt-5.4-nano
#   Batch size  : 50
#   Save every  : 200 batches
#   Max retries : 5 (délai x3 min)
#   Pause 10b   : 30s | Pause 50b : 60s
#   Sortie      : C:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data\recipes_family
# ============================================================
#   🔄 Checkpoint trouvé → reprise passe 2, batch 430
#      (205944 résultats P1, 21500 résultats P2 déjà sauvegardés)
#   ▶️  Reprise depuis passe 2, batch 430
#
#
# 📂 Chargement des données...
#   ✅ 205944 recettes chargées (subset 1)
#   ✅ Dataset ingrédients chargé : 1029720 entrées
#
# ────────────────────────────────────────────────────────────
#   PASSE 1 — Classification par titre seul
# ────────────────────────────────────────────────────────────
#   205944 recettes → 4119 batches de 50
#
#   [Batch 1/4119] recettes 1–50... ✅ 50/50 classifiés
#   [Batch 2/4119] recettes 51–100...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       1 if __name__ == "__main__":
#       2
#       3     #exécuteur 1 → df_all.iloc[0:205944]
#    (...)
#       6     # Exécuteur 4 → df_all.iloc[617832:823776]
#       7     # Exécuteur 5 → df_all.iloc[823776:1029720]
# ----> 9     df, metadata = classify_recipes_pipeline(
#      10          titles_source= recipe.iloc[0:205944],
#      11          ingredients_source= ingredients,
#      12          subset="1",
#      13          api_key= OPENROUTER_API_KEY,
#      14          model_name= MODEL_NAME,
#      15          output_dir= DATA_DIR/"recipes_family",
#      16      )
#      18     # ── Charger les résultats plus tard ─────────────────────────
#      19     # df = load_classification_results("./output_classification/recipe_classifications_subset1_XXXX.csv")
#      20     # pates = get_recipes_by_family(df, "PATES")
#      21     # pates_soupe = get_recipes_by_family(df, "PATES", type_plat="SOUPE")
#      22     # na_recettes = get_na_recipes(df)
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:604, in classify_recipes_pipeline(titles_source, ingredients_source, sqlite_table, api_key, model_name, subset, batch_size, pause_10, pause_50, max_retries, retry_delay_m, output_dir, save_intermediary, save_every_n_batches)
#     600     continue
#     602 print(f"  [Batch {batch_idx+1}/{total_batches}] recettes {start+1}–{end}... ", end="", flush=True)
# --> 604 response = call_llm_recursive(
#     605     client, model_name,
#     606     SYSTEM_PROMPT, batch,
#     607     pass_number=1,
#     608     max_retries=max_retries,
#     609     retry_delay_m=retry_delay_m,
#     610     batch_label=f"P1-{batch_idx+1}",
#     611     depth=0,
#     612 )
#     614 # Validation et stockage (call_llm_recursive retourne toujours une liste)
#     615 valid = 0
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:404, in call_llm_recursive(client, model_name, system_prompt, batch, pass_number, max_retries, retry_delay_m, batch_label, depth)
#     401 else:
#     402     prompt = build_prompt_pass2(batch)
# --> 404 result = _call_llm_single(
#     405     client, model_name,
#     406     system_prompt, prompt,
#     407     max_retries, retry_delay_m,
#     408     batch_label=label,
#     409 )
#     411 # ── Succès → validation des IDs ─────────────────────────────
#     412 if result is not None:
#
# File c:\Users\nguem\Downloads\recipes-20250605T021334Z-1-002\recipes\data mining\recipe_family_classifier_pipe.py:296, in _call_llm_single(client, model_name, system_prompt, user_prompt, max_retries, retry_delay_m, batch_label)
#     294 for attempt in range(1, max_retries + 1):
#     295     try:
# --> 296         completion = client.chat.completions.create(
#     297             extra_headers={
#     298                 "HTTP-Referer": "recipe_family_classifier",
#     299                 "X-Title": "Recipe Family Classification Pipeline",
#     300             },
#     301             model=model_name,
#     302             temperature=0.1,
#     303             messages=[
#     304                 {"role": "system", "content": system_prompt},
#     305                 {"role": "user",   "content": user_prompt},
#     306             ],
#     307         )
#     309         raw = completion.choices[0].message.content.strip()
#     311         # Nettoyage des balises markdown si présentes
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\resources\chat\completions\completions.py:1131, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1086 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1087 def create(
#    1088     self,
#    (...)
#    1128     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1129 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1130     validate_response_format(response_format)
# -> 1131     return self._post(
#    1132         "/chat/completions",
#    1133         body=maybe_transform(
#    1134             {
#    1135                 "messages": messages,
#    1136                 "model": model,
#    1137                 "audio": audio,
#    1138                 "frequency_penalty": frequency_penalty,
#    1139                 "function_call": function_call,
#    1140                 "functions": functions,
#    1141                 "logit_bias": logit_bias,
#    1142                 "logprobs": logprobs,
#    1143                 "max_completion_tokens": max_completion_tokens,
#    1144                 "max_tokens": max_tokens,
#    1145                 "metadata": metadata,
#    1146                 "modalities": modalities,
#    1147                 "n": n,
#    1148                 "parallel_tool_calls": parallel_tool_calls,
#    1149                 "prediction": prediction,
#    1150                 "presence_penalty": presence_penalty,
#    1151                 "prompt_cache_key": prompt_cache_key,
#    1152                 "reasoning_effort": reasoning_effort,
#    1153                 "response_format": response_format,
#    1154                 "safety_identifier": safety_identifier,
#    1155                 "seed": seed,
#    1156                 "service_tier": service_tier,
#    1157                 "stop": stop,
#    1158                 "store": store,
#    1159                 "stream": stream,
#    1160                 "stream_options": stream_options,
#    1161                 "temperature": temperature,
#    1162                 "tool_choice": tool_choice,
#    1163                 "tools": tools,
#    1164                 "top_logprobs": top_logprobs,
#    1165                 "top_p": top_p,
#    1166                 "user": user,
#    1167                 "web_search_options": web_search_options,
#    1168             },
#    1169             completion_create_params.CompletionCreateParamsStreaming
#    1170             if stream
#    1171             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1172         ),
#    1173         options=make_request_options(
#    1174             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1175         ),
#    1176         cast_to=ChatCompletion,
#    1177         stream=stream or False,
#    1178         stream_cls=Stream[ChatCompletionChunk],
#    1179     )
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\openai\_base_client.py:979, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     977 response = None
#     978 try:
# --> 979     response = self._client.send(
#     980         request,
#     981         stream=stream or self._should_stream_response_body(request=request),
#     982         **kwargs,
#     983     )
#     984 except httpx.TimeoutException as err:
#     985     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_client.py:928, in Client.send(self, request, stream, auth, follow_redirects)
#     926 except BaseException as exc:
#     927     response.close()
# --> 928     raise exc
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_client.py:922, in Client.send(self, request, stream, auth, follow_redirects)
#     920 try:
#     921     if not stream:
# --> 922         response.read()
#     924     return response
#     926 except BaseException as exc:
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_models.py:881, in Response.read(self)
#     877 """
#     878 Read and return the response content.
#     879 """
#     880 if not hasattr(self, "_content"):
# --> 881     self._content = b"".join(self.iter_bytes())
#     882 return self._content
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File c:\Users\nguem\Downloads\forage de donnees\devoir1\.conda\lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132         return self._sslobj.read(len, buffer)
#    1133     else:
# -> 1134         return self._sslobj.read(len)
#    1135 except SSLError as x:
#    1136     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
ids = list(df[(df["famille"] == "AUTRE") | (df["type"] == "AUTRE")]['id'])
ids
# Out:
# ['00010379bf',
#  '0001d81db6',
#  '00029f71f7',
#  '0002e15d76',
#  '0004d8bd26',
#  '000566f1e0',
#  '00059576b2']

# %%
df[(df["famille"] == "AUTRE") | (df["type"] == "AUTRE")]
# Out:
#             id                                   title                type  \
# 14  00010379bf           Brown Sugar 'Karintou' Snacks         SNACK_APERO
# 34  0001d81db6                               Guacamole     SAUCE_CONDIMENT
# 40  00029f71f7          Apple Carrot Bones (dog treat)  DESSERT_PATISSERIE
# 42  0002e15d76                    Party Dog Appetizers     SAUCE_CONDIMENT
# 66  0004d8bd26                 Barbecue Baked Potatoes               AUTRE
# 79  000566f1e0                  Grandma's Caramel Corn  DESSERT_PATISSERIE
# 84  00059576b2  My Family's Meat Stuffing for a Turkey               AUTRE
#
#         famille confiance  passe
# 14        AUTRE     basse      2
# 34        AUTRE   moyenne      2
# 40        AUTRE     basse      2
# 42        AUTRE     basse      2
# 66  POMME_TERRE     basse      2
# 79        AUTRE     basse      2
# 84        BOEUF     basse      2

# %%
dict(ingredients[ingredients['id'].isin(ids)][['id', 'ingredient']].values)
# Out:
# {'00010379bf': '200 grams Cake flour 1 tsp Baking powder 20 grams Sugar 7 grams White sesame seeds 70 ml Water 20 cc Vegetable oil 80 grams For candy coating: black sugar 80 grams For candy coating: white sugar 1/4 tsp For candy coating: soy sauce 40 ml For candy coating: water',
#  '0001d81db6': '2 ripe avocados 1 garlic clove, minced 4 ounces cream cheese, at room temperature 12 lime, juice of 1 tablespoon cilantro 4 ounces sour cream fresh jalapeno (to taste) chopped fresh tomato (optional)',
#  '00029f71f7': '2 1/2 cup wheat flour 1/2 cup rolled oats 1 tbsp brown sugar 2 tbsp dried parsley (optional - helps with bad breath) 1 apple - cored, peeled and grated 2 carrots - peeled and grated 1 egg - beaten 1/3 cup vegetable oil 1/4 1/2 cup of water',
#  '0002e15d76': '1 onion, finely chopped 3 tablespoons oil 1 cup ketchup 12 cup water 12 cup cider vinegar 2 14 tablespoons sugar 2 tablespoons Worcestershire sauce 2 tablespoons honey 2 teaspoons mustard powder 2 teaspoons paprika 1 teaspoon salt pepper 18 teaspoon hot pepper sauce (can use more if desired) 1 lemon, sliced (unpeeled) 3 12 lbs mini smoked link sausage or 3 12 lbs hot dogs',
#  '0004d8bd26': "4 large baking potatoes (2 lb./900 g) Safeway 2 pkg For $5.00 thru 02/09 1/2 cup sour cream 1/4 cup Bull's-Eye Bold Original Barbecue Sauce 2 green onions, sliced 1/4 cup French fried onions",
#  '000566f1e0': '1-1/4 gal. popped corn 1 cup butter 2 cups brown sugar, packed 1/2 cup light corn syrup 1/2 tsp. baking soda 1/2 tsp. vanilla',
#  '00059576b2': '2 12 lbs ground beef, your choice of cut 1 lb ground pork, I use Jones Sausage Roll* 1 cup large dice celery 1 cup large dice onion 6 -12 ounces pepperidge farm onion and garlic croutons 1 lb butter, you may not need it all poultry seasoning salt pepper'}
